# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Plotting

# %%
img1=cv2.imread('C:/Users/Anup0/Data Science/Age and Gender Detector/Pictures/Profile CV.jpg')

# %%
plt.imshow(img1)

# %% [markdown]
# Arithmetic Operations

# %%
img2=cv2.imread('C:/Users/Anup0/Data Science/Age and Gender Detector/Pictures/WhatsApp Image 2023-11-15 at 12.14.17_12455cdc.jpg')

# %%
plt.imshow(img2)

# %%
if img1.shape != img2.shape:
    img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# %%
result1=img1+img2

# %%
plt.imshow(result1)

# %%
result2=img1-img2

# %%
plt.imshow(result2)

# %%
result3=img1*img2

# %%
plt.imshow(result3)

# %%
img1_float = img1.astype(np.float32)
img2_float = img2.astype(np.float32)
zero_mask = img2_float == 0
img2_float[zero_mask] = 1e-6
result_float = img1_float / img2_float
result = np.clip(result_float, 0, 255).astype(np.uint8)


plt.imshow(result_float)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255000000.0].

# %%
#img1=cv2.imread("C:/Users/Anup0/Data Science/Age and Gender Detector/Pictures/pexels-pixabay-415829.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
(height, width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
m=cv2.getRotationMatrix2D((width/2, height/2),30,1)
rotate=cv2.warpAffine(img1,m,( height, width))
plt.imshow(rotate)

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
